# %% [markdown]
# <a href="https://colab.research.google.com/github/TiaErikaDev/ExerciciosPython/blob/main/18_Python_Biblioteca_Pandas_importacao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Aula 19 - Importação de Dados no Pandas**

# %% [markdown]
# Exemplo 1: Lendo arquivos de amostras do Google Colab

# %%
import pandas as pd
dados = pd.read_csv('/content/sample_data/california_housing_train.csv')
dados.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
dados.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# Exemplo 2: Lendo arquivos do Google Drive

# %%
netflix = pd.read_csv('/content/drive/MyDrive/Data Science/netflix_titles.csv')
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
frequencia = pd.read_excel('/content/drive/MyDrive/Data Science/FREQUÊNCIA 2ª etapa.xlsx')
frequencia.head()
# Out:
#    Unnamed: 0                           ALUNOS  MATRÍCULA 2022-04-14 00:00:00  \
# 0         1.0         CAIO VITORINO DE ARAUJO   4510879.0             FERIADO
# 1         2.0           CAIO ICARO GOMES SILVA  3216640.0                 NaN
# 2         3.0   CARLA IVANEIDE ALVES DA SILVA   1924299.0                 NaN
# 3         4.0     CARLOS KAUA DA SILVA MACIEL   4860364.0                 NaN
# 4         5.0  EVELYN RAFAELLY DA SILVA ROCHA   4877209.0                 NaN
#
#   2022-04-21 00:00:00 2022-04-28 00:00:00 2022-05-05 00:00:00  \
# 0             FERIADO                   P                   P
# 1                 NaN                   P                   P
# 2                 NaN                   P                   F
# 3                 NaN                   P                   F
# 4                 NaN                   P                   P
#
#   2022-05-12 00:00:00 2022-05-19 00:00:00 2022-05-26 00:00:00  ...  \
# ...

# %%
frequencia.describe()
# Out:
#        Unnamed: 0     MATRÍCULA  2022-06-02 00:00:00  2022-06-09 00:00:00  \
# count   28.000000  2.800000e+01                  0.0                  0.0
# mean    14.500000  4.392502e+06                  NaN                  NaN
# std      8.225975  8.247264e+05                  NaN                  NaN
# min      1.000000  1.924299e+06                  NaN                  NaN
# 25%      7.750000  4.035264e+06                  NaN                  NaN
# 50%     14.500000  4.874092e+06                  NaN                  NaN
# 75%     21.250000  4.888158e+06                  NaN                  NaN
# max     28.000000  4.905422e+06                  NaN                  NaN
#
#        2022-06-23 00:00:00  2022-06-30 00:00:00    PARCIAL  BIMESTRAL  \
# count                  0.0                  0.0  26.000000        0.0
# mean                   NaN                  NaN   8.615385        NaN
# std                    NaN                  NaN   0.982931        NaN
# ...

# %% [markdown]
# Exemplo 3: Lendo arquivos direto do GitHub

# %% [markdown]
# Exemplo 4: Lendo arquivos do seu Computador

# %%
netflix = pd.read_csv('/content/netflix_titles.csv')
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # ***Exercício Proposto***

# %% [markdown]
# Utilize o conjunto de dados encontrado em: https://www.kaggle.com/datasets/gregorut/videogamesales para responder (Faça gráficos, quando pertinente):
#
# - 1. Qual gênero de jogo possui mais títulos? Qual fatura mais?
# - 2. Em que ano houveram mais títulos sendo lançados?
# - 3. Qual o faturamento do jogo de ação no Super Nintendo?
# - 4. Qual foi o jogo mais vendido do NES? Qual foi o melhor ano para esse console?
# - 5. Quais são as publicadoras que mais faturaram? Qual console trouxe mais vendas para a Activision? E para a Ubisoft? E para Capcom?
# - 6. Faça uma tabela dos títulos mais vendidos, por console e gênero:
# - 7. Quantos títulos com a palavra 'Mario' existem? Qual a proporção desses títulos que são da Nintendo? Qual foi a arrecadação total desses títulos? Compara a arrecadação desses títulos com o faturamento total dos consoles.
# - 8. Contunue explorando! Quais perguntas você ainda acha interessante investigar?

# %%
videogame = pd.read_csv('/content/drive/MyDrive/Data Science/vgsales.csv')
videogame.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np

# %%
#1. Qual gênero de jogo possui mais títulos? Qual fatura mais?
videogame['Genre'].value_counts()

# %%
#1. Qual gênero de jogo possui mais títulos? Qual fatura mais?
videogame[['Genre', 'Global_Sales']].value_counts()

# %%
#2. Em que ano houveram mais títulos sendo lançados?
videogame['Year'].value_counts()

# %%
#3. Qual o faturamento do jogo de ação no Super Nintendo?
videogame[videogame['Genre'] == 'Action']['Platform'].value_counts()
# Out:
# PS3     380
# PS2     348
# DS      343
# X360    324
# Wii     238
# PSP     222
# 3DS     182
# GBA     167
# PC      165
# PS      157
# XB      155
# PSV     142
# PS4     122
# GC      101
# XOne     68
# WiiU     63
# 2600     61
# N64      38
# NES      13
# SNES     12
# GB        6
# GEN       3
# SAT       3
# DC        3
# Name: Platform, dtype: int64
